# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, we summarize some of the tools, libraries, and languages that data scientists use. We also perform simple arithmetic operations as examples of basic computations in data science.

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia
# 6. Scala
# 7. C++

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow
# 6. PyTorch
# 7. ggplot2

# %% [markdown]
# ### Data Science Tools
#
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook |
# | RStudio |
# | Apache Zeppelin |
# | Google Colab |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiply then add numbers
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ### Objectives
#
# - List popular languages for Data Science
# - Identify commonly used libraries in Data Science
# - Create a table of Data Science tools
# - Demonstrate basic arithmetic operations using Python
# - Convert minutes into hours

# %% [markdown]
# ## Author
#
# Punya P
